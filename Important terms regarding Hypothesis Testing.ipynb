# %% [markdown]
# #  <span style='color:blue'>Hypothesis Testing</span>
# ## Hypothesis testing is a statistical method that is used in making statistical decisions using experimental data. Hypothesis Testing is basically an assumption that we make about the population parameter.
#
# ###  <span style='color:red'>For understanding the hypothesis testing we have to understand basic term which are use in testing.</span>
#
# ## 1. Normal Distribution:- In simple term distribution with bell-shaped curve.

# %%
#
# Create a normal distribution with mean as 5 and standard deviation as 10
#
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
m = 5
std = 10
snd = stats.norm(m, std)
#
# Generate 1000 random values between -100, 100
#
x = np.linspace(-100, 100, 1000)
#
# Plot the standard normal distribution for different values of random variable
# falling in the range -100, 100
#
plt.figure(figsize=(7.5,7.5))
plt.plot(x, snd.pdf(x))
plt.xlim(-60, 60)
plt.title('Normal Distribution (Mean = 5, STD = 10)', fontsize='15')
plt.xlabel('Values of Random Variable X', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %% [markdown]
# ## 2. Standardised Normal Distribution:- distribution which have mean =0 and variance =1 always.
# *In standard normal distribution we use Z Score to convert normal data into standard form where mean=- and std=1.*
#
# ## $Z Score = X- μ/ σ$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
#
# Create a standard normal distribution with mean as 0 and standard deviation as 1
#
m = 0
std = 1
snd = stats.norm(m, std)
#
# Generate 100 random values between -5, 5
#
x = np.linspace(-5, 5, 100)
#
# Plot the standard normal distribution for different values of random variable
# falling in the range -5, 5
#
plt.figure(figsize=(7.5,7.5))
plt.plot(x, snd.pdf(x))
plt.xlim(-5, 5)
plt.title('standard normal Distribution', fontsize='15')
plt.xlabel('Values of Random Variable X', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %% [markdown]
# ### Important parameter of hypothesis testing
# ### 1. Null hypothesis/(H0): It is a basic assumption or made based on domain or problem knowledge.
# ### 2. Alternative hypothesis (H1): The alternative hypothesis is the hypothesis used in hypothesis testing that is contrary to the null hypothesis.
#
# ### <span style='color:green'>3. Level of significance: Refers to the degree of significance in which we accept or reject the null-hypothesis. 100% accuracy is not possible for accepting or rejecting a hypothesis, so we therefore select a level of significance that is usually 5%.</span>
# #### This is normally denoted with alpha(maths symbol ) and generally it is 0.05 or 5% , which means your output should be 95% confident to give similar kind of result in each sample.
#
# ### *4. Type I error: When we reject the null hypothesis, although that hypothesis was true. Type I error is denoted by alpha. In hypothesis testing, the normal curve that shows the critical region is called the alpha region.*
# ### *5. Type II errors: When we accept the null hypothesis but it is false. Type II errors are denoted by beta. In Hypothesis testing, the normal curve that shows the acceptance region is called the beta region.*
#
#
# ### <span style='color:green'> 6. One tailed test :- A test of a statistical hypothesis , where the region of rejection is on only one side of the sampling distribution , is called a one-tailed test.</span>
# ### <span style='color:green'> 7. Two-tailed test :- A two-tailed test is a statistical test in which the critical area of a distribution is two-sided and tests whether a sample is greater than or less than a certain range of values. </span>
#
# # ![image-2.png](attachment:image-2.png)
#
# ### <span style='color:SlateBlue'>8. P-value :- The P value, or calculated probability, is the probability of finding the observed, or more extreme, results when the null hypothesis (H 0) of a study question is true — the definition of ‘extreme’ depends on how the hypothesis is being tested.</span>
# ### If your P value is less than the chosen significance level then you reject the null hypothesis
# ### $p-value < significance$
# ### If your P value is greater than the chosen significance level then you failed to reject the null hypothesis or we accept the null hypothesis.
# ### $p-value > significance$

# %% [markdown]
# ### some of widely used hypothesis testing type :-
# - T Test ( Student T test)
# - Z Test
# - ANOVA Test
# - Chi-Square Test
